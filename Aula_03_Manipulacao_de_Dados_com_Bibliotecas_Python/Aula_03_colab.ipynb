# %%
# Importando bibliotecas:

# Pandas para poder manipular dados.
import pandas as pd

# Plotly Express para gerar gráficos.
import plotly.express as px

# %%
# Importando Planilha do Excel.
df_principal = pd.read_excel("/content/tabela_de_acoes.xlsx", sheet_name="Principal")

# Mostrando DataFrame.
df_principal
# Out:
#     Ativo       Data  Último (R$)  Var. Dia (%)  Var. Sem. (%)  Var. Mês (%)  \
# 0   USIM5 2024-01-26         9.50          5.20          11.76          2.26
# 1   CMIN3 2024-01-26         6.82          2.40           2.40        -12.11
# 2   PETR3 2024-01-26        41.96          2.19           7.73          7.64
# 3   SUZB3 2024-01-26        52.91          2.04           2.14         -4.89
# 4   CPFE3 2024-01-26        37.10          2.03           2.49         -3.66
# ..    ...        ...          ...           ...            ...           ...
# 76  CRFB3 2024-01-26        10.71         -2.45          -9.47        -13.98
# 77  BHIA3 2024-01-26         8.70         -2.46          -6.95        -23.55
# 78  RENT3 2024-01-26        56.24         -3.63          -6.41        -11.57
# 79  CVCB3 2024-01-26         3.07         -4.36          -5.54        -12.29
# 80  GOLL4 2024-01-26         5.92         -8.07         -15.91        -34.00
#
# ...

# %%
# Lendo tabela Total_de_acoes.
df_total_acoes = pd.read_excel("/content/tabela_de_acoes.xlsx", sheet_name="Total_de_acoes")

# Mostrando DataFrame.
df_total_acoes
# Out:
#                       Código  Qtde. Teórica
# 0                      RRRP3   235665566.00
# 1                      ALOS3   532616595.00
# 2                      ALPA4   176733968.00
# 3                      ABEV3  4394245879.00
# 4                      ARZZ3    62305891.00
# ..                       ...            ...
# 84                     VBBR3  1114412532.00
# 85                     WEGE3  1481593024.00
# 86                     YDUQ3   289347914.00
# 87  Quantidade Teórica Total 96372098181.00
# 88                   Redutor    17047850.79
#
# [89 rows x 2 columns]

# %%
# Lendo tabela Ticker.
df_ticker = pd.read_excel("/content/tabela_de_acoes.xlsx", sheet_name="Ticker")

# Mostrando DataFrame.
df_ticker
# Out:
#     Ticker            Nome
# 0    MGLU3  Magazine Luiza
# 1    HAPV3         Hapvida
# 2    PETR4       Petrobras
# 3    B3SA3              B3
# 4    USIM5        Usiminas
# ..     ...             ...
# 530  TKNO3           Tekno
# 531  COCE6          Coelce
# 532  MGEL3         Mangels
# 533  CTSA8      Santanense
# 534  MMAQ4   Minasmáquinas
#
# [535 rows x 2 columns]

# %%
# Lendo tabela Chatgpt.
df_chatgpt = pd.read_excel("/content/tabela_de_acoes.xlsx", sheet_name="Chatgpt")

# Mostrando DataFrame.
df_chatgpt
# Out:
#      Nome da empresa           Segmento  Idade (anos)
# 0           Usiminas         Siderurgia            60
# 1      CSN Mineração          Mineração             8
# 2          Petrobras           Petróleo            69
# 3             Suzano   Papel e Celulose            94
# 4       CPFL Energia            Energia           109
# ..               ...                ...           ...
# 76  Carrefour Brasil             Varejo            37
# 77       Casas Bahia             Varejo            95
# 78          Localiza  Aluguel de Carros            49
# 79               CVC            Turismo            50
# 80               GOL            Aviação            20
#
# [81 rows x 3 columns]

# %%
# Chamando colunas.
df_principal = df_principal[['Ativo', 'Data', 'Último (R$)', 'Var. Dia (%)']].copy()

# Mostrando DataFrame.
df_principal
# Out:
#     Ativo       Data  Último (R$)  Var. Dia (%)
# 0   USIM5 2024-01-26         9.50          5.20
# 1   CMIN3 2024-01-26         6.82          2.40
# 2   PETR3 2024-01-26        41.96          2.19
# 3   SUZB3 2024-01-26        52.91          2.04
# 4   CPFE3 2024-01-26        37.10          2.03
# ..    ...        ...          ...           ...
# 76  CRFB3 2024-01-26        10.71         -2.45
# 77  BHIA3 2024-01-26         8.70         -2.46
# 78  RENT3 2024-01-26        56.24         -3.63
# 79  CVCB3 2024-01-26         3.07         -4.36
# 80  GOLL4 2024-01-26         5.92         -8.07
#
# [81 rows x 4 columns]

# %%
# Alterando os nomes das colunas.
df_principal = df_principal.rename(columns={'Ativo':'ativo', 'Data':'data', 'Último (R$)':'valor_final', 'Var. Dia (%)':'var_dia_pct'}).copy()

# Mostrando DataFrame.
df_principal
# Out:
#     ativo       data  valor_final  var_dia_pct
# 0   USIM5 2024-01-26         9.50         5.20
# 1   CMIN3 2024-01-26         6.82         2.40
# 2   PETR3 2024-01-26        41.96         2.19
# 3   SUZB3 2024-01-26        52.91         2.04
# 4   CPFE3 2024-01-26        37.10         2.03
# ..    ...        ...          ...          ...
# 76  CRFB3 2024-01-26        10.71        -2.45
# 77  BHIA3 2024-01-26         8.70        -2.46
# 78  RENT3 2024-01-26        56.24        -3.63
# 79  CVCB3 2024-01-26         3.07        -4.36
# 80  GOLL4 2024-01-26         5.92        -8.07
#
# [81 rows x 4 columns]

# %%
# Criando a coluna de valor_inicial.
df_principal['valor_inicial'] = df_principal['valor_final'] / (df_principal['var_dia_pct'] + 1)

# Mostrando DataFrame.
df_principal
# Out:
#     ativo       data  valor_final  var_dia_pct  valor_inicial
# 0   USIM5 2024-01-26         9.50         5.20           1.53
# 1   CMIN3 2024-01-26         6.82         2.40           2.01
# 2   PETR3 2024-01-26        41.96         2.19          13.15
# 3   SUZB3 2024-01-26        52.91         2.04          17.40
# 4   CPFE3 2024-01-26        37.10         2.03          12.24
# ..    ...        ...          ...          ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45          -7.39
# 77  BHIA3 2024-01-26         8.70        -2.46          -5.96
# 78  RENT3 2024-01-26        56.24        -3.63         -21.38
# 79  CVCB3 2024-01-26         3.07        -4.36          -0.91
# 80  GOLL4 2024-01-26         5.92        -8.07          -0.84
#
# [81 rows x 5 columns]

# %%
# Agurpando dados das tabelas Principal e Total de Ações.
df_principal = df_principal.merge(df_total_acoes, left_on='ativo', right_on='Código', how='left')

# Mostrando DataFrame.
df_principal
# Out:
#     ativo       data  valor_final  var_dia_pct  valor_inicial Código  \
# 0   USIM5 2024-01-26         9.50         5.20           1.53  USIM5
# 1   CMIN3 2024-01-26         6.82         2.40           2.01  CMIN3
# 2   PETR3 2024-01-26        41.96         2.19          13.15  PETR3
# 3   SUZB3 2024-01-26        52.91         2.04          17.40  SUZB3
# 4   CPFE3 2024-01-26        37.10         2.03          12.24  CPFE3
# ..    ...        ...          ...          ...            ...    ...
# 76  CRFB3 2024-01-26        10.71        -2.45          -7.39  CRFB3
# 77  BHIA3 2024-01-26         8.70        -2.46          -5.96  BHIA3
# 78  RENT3 2024-01-26        56.24        -3.63         -21.38  RENT3
# 79  CVCB3 2024-01-26         3.07        -4.36          -0.91  CVCB3
# 80  GOLL4 2024-01-26         5.92        -8.07          -0.84  GOLL4
#
#     Qtde. Teórica
# 0    515117391.00
# 1   1110559345.00
# 2   2379877655.00
# 3    683452836.00
# 4    187732538.00
# ..            ...
# ...

# %%
# Removendo coluna Código.
df_principal = df_principal.drop(columns=['Código'])

# Mostrando DataFrame.
df_principal
# Out:
#     ativo       data  valor_final  var_dia_pct  valor_inicial  Qtde. Teórica
# 0   USIM5 2024-01-26         9.50         5.20           1.53   515117391.00
# 1   CMIN3 2024-01-26         6.82         2.40           2.01  1110559345.00
# 2   PETR3 2024-01-26        41.96         2.19          13.15  2379877655.00
# 3   SUZB3 2024-01-26        52.91         2.04          17.40   683452836.00
# 4   CPFE3 2024-01-26        37.10         2.03          12.24   187732538.00
# ..    ...        ...          ...          ...            ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45          -7.39   533990587.00
# 77  BHIA3 2024-01-26         8.70        -2.46          -5.96    94843047.00
# 78  RENT3 2024-01-26        56.24        -3.63         -21.38   853202347.00
# 79  CVCB3 2024-01-26         3.07        -4.36          -0.91   525582771.00
# 80  GOLL4 2024-01-26         5.92        -8.07          -0.84   198184909.00
#
# [81 rows x 6 columns]

# %%
# Crinado coluna variacao_real.
df_principal['variacao_real'] = (df_principal['valor_final'] - df_principal['valor_inicial']) * df_principal['Qtde. Teórica']

# Mostrando DataFrame.
df_principal
# Out:
#     ativo       data  valor_final  var_dia_pct  valor_inicial  Qtde. Teórica  \
# 0   USIM5 2024-01-26         9.50         5.20           1.53   515117391.00
# 1   CMIN3 2024-01-26         6.82         2.40           2.01  1110559345.00
# 2   PETR3 2024-01-26        41.96         2.19          13.15  2379877655.00
# 3   SUZB3 2024-01-26        52.91         2.04          17.40   683452836.00
# 4   CPFE3 2024-01-26        37.10         2.03          12.24   187732538.00
# ..    ...        ...          ...          ...            ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45          -7.39   533990587.00
# 77  BHIA3 2024-01-26         8.70        -2.46          -5.96    94843047.00
# 78  RENT3 2024-01-26        56.24        -3.63         -21.38   853202347.00
# 79  CVCB3 2024-01-26         3.07        -4.36          -0.91   525582771.00
# 80  GOLL4 2024-01-26         5.92        -8.07          -0.84   198184909.00
#
#     variacao_real
# 0   4104322437.97
# ...

# %%
# Formatar números flutuantes com duas casas depois da vírgula.
pd.options.display.float_format = '{:.2f}'.format

# %%
# Formatando a Coluna Qtde. Teórica em números inteiros.
df_principal['Qtde. Teórica'] = df_principal['Qtde. Teórica'].astype(int)

# Mostrando DataFrame.
df_principal
# Out:
#     ativo       data  valor_final  var_dia_pct  valor_inicial  Qtde. Teórica  \
# 0   USIM5 2024-01-26         9.50         5.20           1.53      515117391
# 1   CMIN3 2024-01-26         6.82         2.40           2.01     1110559345
# 2   PETR3 2024-01-26        41.96         2.19          13.15     2379877655
# 3   SUZB3 2024-01-26        52.91         2.04          17.40      683452836
# 4   CPFE3 2024-01-26        37.10         2.03          12.24      187732538
# ..    ...        ...          ...          ...            ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45          -7.39      533990587
# 77  BHIA3 2024-01-26         8.70        -2.46          -5.96       94843047
# 78  RENT3 2024-01-26        56.24        -3.63         -21.38      853202347
# 79  CVCB3 2024-01-26         3.07        -4.36          -0.91      525582771
# 80  GOLL4 2024-01-26         5.92        -8.07          -0.84      198184909
#
#     variacao_real
# 0   4104322437.97
# ...

# %%
# Trasendo a coluna de identificação das ações que Subiram, Desceram e as que se manteram Estáveis.
df_principal['Resultado'] = df_principal['variacao_real'].apply(lambda x: 'Subiu' if x > 0 else('Desceu' if x < 0 else 'Estável'))

# Mostrar DataFrame
df_principal
# Out:
#     ativo       data  valor_final  var_dia_pct  valor_inicial  Qtde. Teórica  \
# 0   USIM5 2024-01-26         9.50         5.20           1.53      515117391
# 1   CMIN3 2024-01-26         6.82         2.40           2.01     1110559345
# 2   PETR3 2024-01-26        41.96         2.19          13.15     2379877655
# 3   SUZB3 2024-01-26        52.91         2.04          17.40      683452836
# 4   CPFE3 2024-01-26        37.10         2.03          12.24      187732538
# ..    ...        ...          ...          ...            ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45          -7.39      533990587
# 77  BHIA3 2024-01-26         8.70        -2.46          -5.96       94843047
# 78  RENT3 2024-01-26        56.24        -3.63         -21.38      853202347
# 79  CVCB3 2024-01-26         3.07        -4.36          -0.91      525582771
# 80  GOLL4 2024-01-26         5.92        -8.07          -0.84      198184909
#
#     variacao_real Resultado
# ...

# %%
# Agrupando Tabelas: Principal com Tiker.
df_principal = df_principal.merge(df_ticker, left_on='ativo', right_on='Ticker', how='left')

# Removendo coluna
df_principal = df_principal.drop(columns=['Ticker'])

# Mostrando DataFrame
df_principal
# Out:
#     ativo       data  valor_final  var_dia_pct  valor_inicial  Qtde. Teórica  \
# 0   USIM5 2024-01-26         9.50         5.20           1.53      515117391
# 1   CMIN3 2024-01-26         6.82         2.40           2.01     1110559345
# 2   PETR3 2024-01-26        41.96         2.19          13.15     2379877655
# 3   SUZB3 2024-01-26        52.91         2.04          17.40      683452836
# 4   CPFE3 2024-01-26        37.10         2.03          12.24      187732538
# ..    ...        ...          ...          ...            ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45          -7.39      533990587
# 77  BHIA3 2024-01-26         8.70        -2.46          -5.96       94843047
# 78  RENT3 2024-01-26        56.24        -3.63         -21.38      853202347
# 79  CVCB3 2024-01-26         3.07        -4.36          -0.91      525582771
# 80  GOLL4 2024-01-26         5.92        -8.07          -0.84      198184909
#
# ...

# %%
# Agrupando Tabelas: Principal com ChatGPT.
df_principal = df_principal.merge(df_chatgpt, left_on='Nome', right_on='Nome da empresa', how='left')

# Removendo coluna
df_principal = df_principal.drop(columns=['Nome da empresa'])

# Mostrando DataFrame
df_principal
# Out:
#     ativo       data  valor_final  var_dia_pct  valor_inicial  Qtde. Teórica  \
# 0   USIM5 2024-01-26         9.50         5.20           1.53      515117391
# 1   CMIN3 2024-01-26         6.82         2.40           2.01     1110559345
# 2   PETR3 2024-01-26        41.96         2.19          13.15     2379877655
# 3   PETR3 2024-01-26        41.96         2.19          13.15     2379877655
# 4   SUZB3 2024-01-26        52.91         2.04          17.40      683452836
# ..    ...        ...          ...          ...            ...            ...
# 82  CRFB3 2024-01-26        10.71        -2.45          -7.39      533990587
# 83  BHIA3 2024-01-26         8.70        -2.46          -5.96       94843047
# 84  RENT3 2024-01-26        56.24        -3.63         -21.38      853202347
# 85  CVCB3 2024-01-26         3.07        -4.36          -0.91      525582771
# 86  GOLL4 2024-01-26         5.92        -8.07          -0.84      198184909
#
# ...

# %%
# Alterando os nomes das colunas.
df_principal = df_principal.rename(columns={'Qtde. Teórica':'qtde_ativos', 'Resultado':'status', 'Nome':'nome', 'Segmento':'segmento', 'Idade (anos)':'idade'}).copy()

# Mostrando DataFrame.
df_principal
# Out:
#     ativo       data  valor_final  var_dia_pct  valor_inicial  qtde_ativos  \
# 0   USIM5 2024-01-26         9.50         5.20           1.53    515117391
# 1   CMIN3 2024-01-26         6.82         2.40           2.01   1110559345
# 2   PETR3 2024-01-26        41.96         2.19          13.15   2379877655
# 3   PETR3 2024-01-26        41.96         2.19          13.15   2379877655
# 4   SUZB3 2024-01-26        52.91         2.04          17.40    683452836
# ..    ...        ...          ...          ...            ...          ...
# 82  CRFB3 2024-01-26        10.71        -2.45          -7.39    533990587
# 83  BHIA3 2024-01-26         8.70        -2.46          -5.96     94843047
# 84  RENT3 2024-01-26        56.24        -3.63         -21.38    853202347
# 85  CVCB3 2024-01-26         3.07        -4.36          -0.91    525582771
# 86  GOLL4 2024-01-26         5.92        -8.07          -0.84    198184909
#
#     variacao_real status              nome           segmento  idade
# ...

# %%
# Trasendo a coluna de categoria de idade.
df_principal['Cat_idade'] = df_principal['idade'].apply(lambda x: 'Mais de 100' if x > 0 else('Menos de 50' if x < 0 else 'Entre 50 e 100'))

# Mostrar DataFrame
df_principal
# Out:
#     ativo       data  valor_final  var_dia_pct  valor_inicial  qtde_ativos  \
# 0   USIM5 2024-01-26         9.50         5.20           1.53    515117391
# 1   CMIN3 2024-01-26         6.82         2.40           2.01   1110559345
# 2   PETR3 2024-01-26        41.96         2.19          13.15   2379877655
# 3   PETR3 2024-01-26        41.96         2.19          13.15   2379877655
# 4   SUZB3 2024-01-26        52.91         2.04          17.40    683452836
# ..    ...        ...          ...          ...            ...          ...
# 82  CRFB3 2024-01-26        10.71        -2.45          -7.39    533990587
# 83  BHIA3 2024-01-26         8.70        -2.46          -5.96     94843047
# 84  RENT3 2024-01-26        56.24        -3.63         -21.38    853202347
# 85  CVCB3 2024-01-26         3.07        -4.36          -0.91    525582771
# 86  GOLL4 2024-01-26         5.92        -8.07          -0.84    198184909
#
# ...

# %%
# Alterando os nomes das colunas.
df_principal = df_principal.rename(columns={'Cat_idade':'cat_idade'}).copy()

# Mostrando DataFrame.
df_principal
# Out:
#     ativo       data  valor_final  var_dia_pct  valor_inicial  qtde_ativos  \
# 0   USIM5 2024-01-26         9.50         5.20           1.53    515117391
# 1   CMIN3 2024-01-26         6.82         2.40           2.01   1110559345
# 2   PETR3 2024-01-26        41.96         2.19          13.15   2379877655
# 3   PETR3 2024-01-26        41.96         2.19          13.15   2379877655
# 4   SUZB3 2024-01-26        52.91         2.04          17.40    683452836
# ..    ...        ...          ...          ...            ...          ...
# 82  CRFB3 2024-01-26        10.71        -2.45          -7.39    533990587
# 83  BHIA3 2024-01-26         8.70        -2.46          -5.96     94843047
# 84  RENT3 2024-01-26        56.24        -3.63         -21.38    853202347
# 85  CVCB3 2024-01-26         3.07        -4.36          -0.91    525582771
# 86  GOLL4 2024-01-26         5.92        -8.07          -0.84    198184909
#
# ...

# %%
# Calculando o maior valor.
maior = df_principal['variacao_real'].max()

# Calculando o menor valor.
menor = df_principal['variacao_real'].min()

# Calculando a média.
media = df_principal['variacao_real'].mean()

# Calculando a média de quem Subiu.
media_subiu = df_principal[df_principal['status'] == 'Subiu']['variacao_real'].mean()

# Calculando a média de quem Desceu.
media_desceu = df_principal[df_principal['status'] == 'Desceu']['variacao_real'].mean()

# Impressão dos resultados.
print(f"Maior\tR$ {maior:,.2f}")
print(f"Menor\tR$ {menor:,.2f}")
print(f"Média\tR$ {media:,.2f}")
print(f"Média de quem subiu\tR$ {media_subiu:,.2f}")
print(f"Média de quem desceu\tR$ {media_desceu:,.2f}")
# Out:
# Maior	R$ 206,334,751,779.56
# Menor	R$ -150,291,187,744.73
# Média	R$ 14,680,230,968.88
# Média de quem subiu	R$ 26,122,596,866.49
# Média de quem desceu	R$ -21,039,435,101.47

# %%
# Trazendo apenas os que subiram.
df_principal_subiu = df_principal[df_principal['status'] == 'Subiu']

# Mostrando DataFrame.
df_principal_subiu
# Out:
#     ativo       data  valor_final  var_dia_pct  valor_inicial  qtde_ativos  \
# 0   USIM5 2024-01-26         9.50         5.20           1.53    515117391
# 1   CMIN3 2024-01-26         6.82         2.40           2.01   1110559345
# 2   PETR3 2024-01-26        41.96         2.19          13.15   2379877655
# 3   PETR3 2024-01-26        41.96         2.19          13.15   2379877655
# 4   SUZB3 2024-01-26        52.91         2.04          17.40    683452836
# ..    ...        ...          ...          ...            ...          ...
# 82  CRFB3 2024-01-26        10.71        -2.45          -7.39    533990587
# 83  BHIA3 2024-01-26         8.70        -2.46          -5.96     94843047
# 84  RENT3 2024-01-26        56.24        -3.63         -21.38    853202347
# 85  CVCB3 2024-01-26         3.07        -4.36          -0.91    525582771
# 86  GOLL4 2024-01-26         5.92        -8.07          -0.84    198184909
#
# ...

# %%
# Agrupando por segmento e somando as variações.
df_principal_segmento = df_principal_subiu.groupby('segmento')['variacao_real'].sum().reset_index()

# Mostrando DataFrame.
df_principal_segmento
# Out:
#               segmento   variacao_real
# 0          Aeronáutica  57595204072.00
# 1            Alimentos  22962846989.74
# 2    Aluguel de Carros  66229004936.45
# 3              Aviação   4082245419.49
# 4      Açúcar e Álcool   8286360606.00
# 5                Banco 219147523836.68
# 6     Bolsa de Valores 206334751779.56
# 7           Construção  23734239174.42
# 8           Cosméticos  46476769071.09
# 9             Educação   3211457268.65
# 10             Energia  55762128187.51
# 11        Farmacêutica  33590832175.50
# 12             Holding  24604691734.84
# 13         Imobiliário   1028676477.34
# 14           Logística  12961780478.91
# 15  Meios de Pagamento   2418443757.10
# 16           Mineração 187376122114.15
# 17                Moda  23934145834.66
# 18    Papel e Celulose  24266262726.19
# 19            Petróleo 399351868262.30
# 20             Química   2894003675.47
# 21               Saúde 114362864719.19
# 22    Shopping Centers   4635382031.92
# ...

# %%
# Agrupando por Saldo.
df_analise_saldo = df_principal.groupby('status')['variacao_real'].sum().reset_index()

# Mostrando DataFrame.
df_analise_saldo
# Out:
#     status    variacao_real
# 0   Desceu -420788702029.31
# 1  Estável             0.00
# 2    Subiu 1697968796322.04

# %%
# Criando gráfico de Análise de saldo.
fig_analise_saldo = px.bar(df_analise_saldo, x='status', y='variacao_real', text='variacao_real', text_auto='.2s', title='Variação em reais(R$) por Status', hover_data={'variacao_real': ':.2f'})

# Mostrando o gráfico.
fig_analise_saldo.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Criando gráfico de Variação por segmento.
fig_pct_segmento = px.pie(df_principal_segmento, values='variacao_real', names='segmento', title='Percentual por Segmento', labels={'variacao_real': 'Variação em reais(R$)', 'segmento': 'Segmento'}, hover_data={'variacao_real': ':.2f'})

# Mostrando o gráfico.
fig_pct_segmento.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
